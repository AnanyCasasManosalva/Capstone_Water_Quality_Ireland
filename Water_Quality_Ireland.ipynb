# %% [markdown]
# # Names of rivers throughout Ireland

# %%
import pandas as pd

# %%
name_rivers = pd.read_excel("Dataset_selected/WaterQuality/MON_QRecords/MON_QRecords_LatestYear.xlsx")

# %%
name_rivers.head(5)
# Out:
#    StationCode                                   StationName StationTypeEDEN  \
# 0  RS01B010100                 Br. u/s Mourne Beg Confluence   RIVER_STATION
# 1  RS01B020010                                 Blackburn Br.   RIVER_STATION
# 2  RS01B020100                       At Burn Daurnett Bridge   RIVER_STATION
# 3  RS01B020200                     Bridge N.W. of Daisy Hill   RIVER_STATION
# 4  RS01B020300  BURN DAURNETT - Br just u/s Finn River confl   RIVER_STATION
#
#    RiverWaterbodyName     EntityName EntityCode  LatestYear QValueScore  \
# 0      BUNADAOWEN_010     BUNADAOWEN      01B01        2022          4*
# 1   BURN DAURNETT_010  BURN DAURNETT      01B02        2022         3-4
# 2   BURN DAURNETT_010  BURN DAURNETT      01B02        1990         3-4
# 3   BURN DAURNETT_010  BURN DAURNETT      01B02        2022         3-4
# 4  FINN (DONEGAL)_060  BURN DAURNETT      01B02        1990           3
#
#   QValueStatus      WFDWISECODE  ...          LocalAuthority  \
# ...

# %% [markdown]
# ## Neagh Bann Basin

# %%
filtered_df = name_rivers[name_rivers['RiverBasinDistrict'] == 'Neagh Bann']
unique_rivers_Neagh_Bann = filtered_df['RiverWaterbodyName'].dropna().unique()
print(unique_rivers_Neagh_Bann)
# Out:
# ['BLACKWATER (MONAGHAN)_010' 'BLACKWATER (MONAGHAN)_020'
#  'BLACKWATER (MONAGHAN)_030' 'BLACKWATER (MONAGHAN)_040'
#  'CLONTIBRET STREAM_010' 'CLONTIBRET STREAM_020' 'CLONTIBRET STREAM_030'
#  'CONAWARY (LOWER)_010' 'CONAWARY (LOWER)_020' 'MOUNTAIN WATER_010'
#  'MOUNTAIN WATER_020' 'MOUNTAIN WATER_030' 'MOUNTAIN WATER_040'
#  'MOUNTAIN WATER_050' 'SHAMBLES_010' 'SCOTSTOWN_010' 'SCOTSTOWN_020'
#  'ANNAHALE STREAM_010' 'BIG (LOUTH)_010' 'BIG (LOUTH)_020'
#  'BALLYMASCANLAN_010' 'FLURRY_030' 'FANE_050' 'TERMONFECKIN_020'
#  'CASTLETOWN_010' 'CASTLETOWN_020' 'CASTLETOWN_030' 'CULLY WATER_010'
#  'COUNTY WATER_010' 'FANE_020' 'FANE_010' 'DEE_010' 'DEE_020' 'DEE_030'
#  'MOYNAGH_040' 'DEE_040' 'DEE_050' 'DEE_060' 'DEE_070' 'DEE_080' 'DEE_090'
#  'TERMONFECKIN_010' 'GLYDE_010' 'FANE_030' 'FANE_040' 'FANE_060'
#  'FLURRY_010' 'FLURRY_020' 'GLYDE_020' 'GLYDE_030' 'GLYDE_040' 'GLYDE_050'
#  'GLYDE_060' 'GLYDE_070' "GENTLE OWEN'S LAKE STREAM_010"
# ...

# %%
unique_rivers_Neagh_Bann = filtered_df['RiverWaterbodyName'].dropna().nunique()
print("Number of unique rivers in Neagh Bann:", unique_rivers_Neagh_Bann)
# Out:
# Number of unique rivers in Neagh Bann: 70

# %%
# pip install rasterio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import rasterio
import matplotlib.pyplot as plt

# Ruta a la carpeta que contiene los archivos del Esri Grid
esri_grid_folder = 'phosphorus-manure-europe-grid/pman_europe'

# Abrir el archivo Esri Grid
with rasterio.open(esri_grid_folder) as src:
    data = src.read(1)  # Leer la primera banda
    plt.imshow(data, cmap='viridis')
    plt.colorbar()
    plt.title('Esri Grid Visualization')
    plt.show()
# Out:
# C:\Users\TOSHIBA\anaconda3\Lib\site-packages\matplotlib\image.py:505: RuntimeWarning: overflow encountered in multiply
#   A_resampled *= ((a_max - a_min) / frac)

# %% [markdown]
# ## Eastern Basin

# %%
filtered_df = name_rivers[name_rivers['RiverBasinDistrict'] == 'Eastern']
unique_rivers_Eastern = filtered_df['RiverWaterbodyName'].dropna().unique()
print(unique_rivers_Eastern)
# Out:
# ['ATHBOY_010' 'ATHBOY_020' 'ATHBOY_030' 'ATHBOY_040' 'ATHBOY_050'
#  'ATHBOY_060' 'BLACKWATER (KELLS)_010' 'BLACKWATER (KELLS)_020'
#  'BLACKWATER (KELLS)_030' 'BLACKWATER (KELLS)_040'
#  'BLACKWATER (KELLS)_050' 'BLACKWATER (KELLS)_060'
#  'BLACKWATER (KELLS)_070' 'BLACKWATER (KELLS)_080'
#  'BLACKWATER (KELLS)_090' 'BLACKWATER (KELLS)_100'
#  'BLACKWATER (KELLS)_110' 'BLACKWATER (KELLS)_120'
#  'BLACKWATER (LONGWOOD)_010' 'BLACKWATER (LONGWOOD)_020'
#  'BLACKWATER (LONGWOOD)_030' 'BLACKWATER (LONGWOOD)_040'
#  'BLACKWATER (LONGWOOD)_050' 'BOYCETOWN_010' 'BOYCETOWN_020' 'BOYNE_010'
#  'BOYNE_020' 'BOYNE_030' 'BOYNE_040' 'BOYNE_050' 'BOYNE_060' 'BOYNE_070'
#  'BOYNE_080' 'BOYNE_090' 'BOYNE_100' 'BOYNE_110' 'BOYNE_120' 'BOYNE_130'
#  'BOYNE_140' 'BOYNE_150' 'BOYNE_160' 'BOYNE_170' 'Boyne_180'
#  'CLADY (MEATH)_010' 'CLADY (MEATH)_020' 'CROSS WATER_010'
#  'CASTLEJORDAN_010' 'CASTLEJORDAN_020' 'CASTLEJORDAN_030'
#  'YELLOW (CASTLEJORDAN)_030' 'CHAPEL LAKE STREAM_010'
# ...

# %%
unique_rivers_Eastern = filtered_df['RiverWaterbodyName'].dropna().nunique()
print("Number of unique rivers in Eastern:", unique_rivers_Eastern)
# Out:
# Number of unique rivers in Eastern: 261

# %% [markdown]
# ## North Western Basin

# %%
filtered_df = name_rivers[name_rivers['RiverBasinDistrict'] == 'North Western']
unique_rivers_North_Western = filtered_df['RiverWaterbodyName'].dropna().unique()
print(unique_rivers_North_Western)
# Out:
# ['BUNADAOWEN_010' 'BURN DAURNETT_010' 'FINN (DONEGAL)_060' 'CARRIGANS_010'
#  'CUMMIRK_010' 'CUMMIRK_020' 'CROSS ROADS STREAM_010' 'CLOGHROE_010'
#  'CLOGHER (FINN)_010' 'FINN (DONEGAL)_040' 'DEELE (DONEGAL)_010'
#  'DEELE (DONEGAL)_020' 'DEELE (DONEGAL)_030' 'DEELE (DONEGAL)_040'
#  'DEELE (DONEGAL)_050' 'REELAN_010' 'ELATAGH_010' 'ELATAGH_020'
#  'FINN (DONEGAL)_010' 'FINN (DONEGAL)_020' 'FINN (DONEGAL)_030'
#  'FINN (DONEGAL)_050' 'FINN (DONEGAL)_070' 'FINN (DONEGAL)_080'
#  'MOURNE BEG_010' 'Mourne Beg River (Derrygoonan)' 'REELAN_020'
#  'ROUGH BURN_010' 'ST JOHNSTON_010' 'STRANAGOPPOGE_010' 'SWILLY BURN_010'
#  'SWILLY BURN_020' 'SWILLY BURN_030' 'GLENANIFF_010' 'DROWES_010'
#  'BRADOGE_010' 'BRADOGE_020' 'DUFF_010' 'DUFF_020' 'DUFF_030' 'ABBEY_010'
#  'ANNALEE_010' 'ANNALEE_020' 'ANNALEE_030' 'ANNALEE_040' 'ANNALEE_050'
#  'ANNALEE_060' 'ANNALEE_070' 'ANNALEE_080' 'ANNALEE_090' 'ANNALEE_100'
#  'AGHACASHLAUN_010' 'AGHACASHLAUN_020' 'ADHACASHLAUN_030'
# ...

# %%
unique_rivers_North_Western = filtered_df['RiverWaterbodyName'].dropna().nunique()
print("Number of unique rivers in North Western:", unique_rivers_North_Western)
# Out:
# Number of unique rivers in North Western: 288

# %% [markdown]
# ## South Western Basin

# %%
filtered_df = name_rivers[name_rivers['RiverBasinDistrict'] == 'South Western']
unique_rivers_South_Western = filtered_df['RiverWaterbodyName'].dropna().unique()
print(unique_rivers_South_Western)
# Out:
# ['ALLOW_010' 'ALLOW_030' 'ALLOW_040' 'ALLOW_050' 'ALLOW_060' 'ALLOW_070'
#  'ARAGLIN (BLACKWATER)_010' 'ARAGLIN (BLACKWATER)_020'
#  'ARAGLIN (BLACKWATER)_030' 'ARAGLIN (BLACKWATER)_040'
#  'AWBEG (Buttevant)_010' 'AWBEG (Buttevant)_020' 'AWBEG (Buttevant)_030'
#  'AWBEG (Buttevant)_040' 'AWBEG (Buttevant)_050' 'AWBEG (Buttevant)_060'
#  'AWBEG (Buttevant)_070' 'BLACKWATER (MUNSTER)_090' 'AWNASKIRTAUN_010'
#  'BLACKWATER (MUNSTER)_050' 'AWBEG (BUTTEVANT) (EAST)_010'
#  'AWBEG (BUTTEVANT) (EAST)_020' 'AWBEG (BUTTEVANT) (WEST)_010'
#  'AWBEG (BUTTEVANT) (WEST)_020' 'BEHANAGH_010' 'FUNSHION_020'
#  'BLACKWATER (MUNSTER)_010' 'BLACKWATER (MUNSTER)_020'
#  'BLACKWATER (MUNSTER)_030' 'BLACKWATER (MUNSTER)_040'
#  'BLACKWATER (MUNSTER)_060' 'BLACKWATER (MUNSTER)_070'
#  'BLACKWATER (MUNSTER)_080' 'BLACKWATER (MUNSTER)_100'
#  'BLACKWATER (MUNSTER)_110' 'BLACKWATER (MUNSTER)_120'
#  'BLACKWATER (MUNSTER)_140' 'BLACKWATER (MUNSTER)_150'
# ...

# %%
unique_rivers_South_Western = filtered_df['RiverWaterbodyName'].dropna().nunique()
print("Number of unique rivers in South Western:", unique_rivers_South_Western)
# Out:
# Number of unique rivers in South Western: 400

# %% [markdown]
# ## Western Basin

# %%
filtered_df = name_rivers[name_rivers['RiverBasinDistrict'] == 'Western']
unique_rivers_Western = filtered_df['RiverWaterbodyName'].dropna().unique()
print(unique_rivers_Western)
# Out:
# ['KILCOLGAN_040' 'BEAGH_010' 'BALLYMABILLA_010' 'BOLEYNEENDORRISH_010'
#  'BOLEYNEENDORRISH_020' 'BOLEYNEENDORRISH_030' 'CANNAHOWNA_010'
#  'CLARINBRIDGE_010' 'CLARINBRIDGE_020' 'CLARINBRIDGE_030'
#  'CLARINBRIDGE_040' 'CLARINBRIDGE_050' 'CARRA STREAM_010'
#  'CARRA STREAM_020' 'KILCOLGAN_010' 'KILCOLGAN_020' 'KILCOLGAN_030'
#  'KILCHREEST_010' 'OWENDALULLEEGH_030' 'LECARROW STREAM_010'
#  'OWENDALULLEEGH_010' 'OWENDALULLEEGH_020' 'OWENDALULLEEGH_040'
#  'OWENDALULLEEGH_050' 'RAFORD_010' 'RAFORD_020' 'RAFORD_030'
#  'TOBERDONEY_010' 'TOBERDONEY_020' 'ABBERT_010' 'ABBERT_020' 'ABBERT_030'
#  'ABBERT_040' 'AILLE (MAYO)_010' 'AILLE (MAYO)_020' 'AILLE (MAYO)_030'
#  'AILLE (MAYO)_040' 'AGHINISH_010' 'ANNIES_010' 'BEALANABRACK_010'
#  'BEALANABRACK_020' 'BLACK (SHRULE)_010' 'BLACK (SHRULE)_020'
#  'BLACK (SHRULE)_030' 'BALLINDINE_010' 'BALLINDUFF STREAM_010'
#  'OWENRIFF (CORRIB)_020' 'BALLYCUIRKE_010' 'CLARE (GALWAY)_010'
#  'CLARE (GALWAY)_020' 'CLARE (GALWAY)_030' 'CLARE (GALWAY)_040'
# ...

# %%
unique_rivers_Western = filtered_df['RiverWaterbodyName'].dropna().nunique()
print("Number of unique rivers in Western:", unique_rivers_Western)
# Out:
# Number of unique rivers in Western: 393

# %% [markdown]
# ## South Eastern Basin

# %%
filtered_df = name_rivers[name_rivers['RiverBasinDistrict'] == 'South Eastern']
unique_rivers_South_Eastern = filtered_df['RiverWaterbodyName'].dropna().unique()
print(unique_rivers_South_Eastern)
# Out:
# ['AUGHBOY (WEXFORD)_010' 'ASKINCH UPPER STREAM_010' 'BALLYEDMOND_010'
#  'OWENAVORRAGH_030' 'BANOGE_010' 'BANOGE_020' 'BANOGE_030'
#  'BLACKWATER (WEXFORD)_010' 'BRACKAN_010' 'CLONOUGH_010'
#  'INCH (WEXFORD)_020' 'GORTEEN UPPER STREAM_010' 'INCH (WEXFORD)_010'
#  'OWENAVORRAGH_010' 'OWENAVORRAGH_020' 'OWENAVORRAGH_040'
#  'OWENAVORRAGH_050' 'OWENAVORRAGH_060' 'ASSALY_010'
#  'ASKINVILLAR STREAM_010' 'URRIN_020' 'BANN_010' 'BANN_020' 'BANN_030'
#  'BANN_040' 'BANN_050' 'BANN_060' 'BANN_070' 'BORO_010' 'BORO_020'
#  'BORO_030' 'BORO_040' 'BORO_050' 'BORO_060' "BROWN'S BECK BROOK_010"
#  'BLACKLION STREAM (CARLOW)_010' 'BLACKLION STREAM (CARLOW)_020'
#  'BORRIS STREAM (SLANEY)_010' 'BALLINGALE STREAM_010'
#  'BALLINGALE STREAM_020' 'BALLYCARNEY STREAM_010' 'BALLYCARNEY STREAM_020'
#  'BLACKWATER STREAM (BANN)_010' 'Ballaghmore Distributary_010' 'CLODY_010'
#  'CLODY_020' 'SLANEY_120' 'CORBALLY STREAM_010' 'CORBALLY STREAM_020'
# ...

# %%
unique_rivers_South_Eastern = filtered_df['RiverWaterbodyName'].dropna().nunique()
print("Number of unique rivers in South Eastern:", unique_rivers_South_Eastern)
# Out:
# Number of unique rivers in South Eastern: 522

# %% [markdown]
# ## Shannon Basin

# %%
filtered_df = name_rivers[name_rivers['RiverBasinDistrict'] == 'Shannon']
unique_rivers_Shannon = filtered_df['RiverWaterbodyName'].dropna().unique()
print(unique_rivers_Shannon)
# Out:
# ['ALLAGHAUN_010' 'ALLAGHAUN_020' 'ALLAGHAUN_030' 'ALLAGHAUN_040'
#  'BREANAGH_010' 'BRICK_010' 'BRICK_020' 'CAHER (LIMERICK)_010'
#  'CLYDAGH (FEALE)_010' 'CLYDAGH (FEALE)_020' 'OWENMORE (KERRY)_010'
#  'FEALE_010' 'FEALE_020' 'FEALE_030' 'FEALE_040' 'FEALE_050' 'FEALE_060'
#  'FEALE_070' 'FEALE_080' 'FEALE_090' 'FEOHANAGH_010' 'FEOHANAGH_020'
#  'FINGLAS (TRALEE BAY)_010' 'GALEY_010' 'GALEY_020' 'GALEY_030'
#  'GALEY_040' 'GALEY_050' 'GLASHACOONCORE_010' 'GLASHOREAG_010'
#  'GLENNAHOO_010' 'GLENACARNEY_010' 'KNOCKFINNISK_010' 'LEE (TRALEE)_010'
#  'LEE (TRALEE)_020' 'LEE (TRALEE)_030' 'LYRACRUMPANE_010' 'OOLAGH_010'
#  'OOLAGH_020' 'OWENCASHLA_010' 'OWENAFEANNA_010' 'OWVEG (KERRY)_010'
#  'OWVEG (KERRY)_020' 'SCORID_010' 'SMEARLAGH_010' 'SMEARLAGH_020'
#  'SMEARLAGH_030' 'SMEARLAGH_040' 'TULLALEAGUE_010' 'TYSHE_010' 'TYSHE_020'
#  'TARMON STREAM_010' 'AHACRONANE_010' 'AHACRONANE_020'
#  'AHAVARRAGA STREAM_010' 'ARRA_010' 'DEEL (NEWCASTLEWEST)_090'
# ...

# %%
unique_rivers_Shannon = filtered_df['RiverWaterbodyName'].dropna().nunique()
print("Number of unique rivers in Shannon", unique_rivers_Shannon)
# Out:
# Number of unique rivers in Shannon 596

# %% [markdown]
# ### Shannon river has local authorities of Cavan, Clare, Cork, Galway, Kerry, Laois, Leitrim, Limerick city, Longford, Mayo, Meath, Offaly, Roscommon, Sligo, Tipperary and Westmeath

# %% [markdown]
# ### Select tributaries of the river Shannon belonging to Clare, Galway, Kerry, Limerick city, Mayo and Tipperary

# %%
# Filter rows by specified local authorities
local_authorities = [
    'CLARE COUNTY COUNCIL', 
    'GALWAY COUNTY COUNCIL', 
    'KERRY COUNTY COUNCIL', 
    'Limerick City & County Council',     
    'MAYO COUNTY COUNCIL',
    'Tipperary County Council'
]
filtered_authority_df = filtered_df[filtered_df['LocalAuthority'].isin(local_authorities)]

# %%
# Select the unique names of rivers in the specified local authority areas 
unique_rivers_authorities = filtered_authority_df['RiverWaterbodyName'].dropna().unique()
print("\nUnique rivers in the specified local authority areas:")
print(unique_rivers_authorities)
# Out:
# Unique rivers in the specified local authority areas:
# ['ALLAGHAUN_010' 'ALLAGHAUN_020' 'ALLAGHAUN_030' 'ALLAGHAUN_040'
#  'BRICK_010' 'BRICK_020' 'CAHER (LIMERICK)_010' 'CLYDAGH (FEALE)_010'
#  'CLYDAGH (FEALE)_020' 'OWENMORE (KERRY)_010' 'FEALE_030' 'FEALE_040'
#  'FEALE_050' 'FEALE_060' 'FEALE_070' 'FEALE_080' 'FEALE_090'
#  'FEOHANAGH_010' 'FEOHANAGH_020' 'FINGLAS (TRALEE BAY)_010' 'GALEY_010'
#  'GALEY_020' 'GALEY_030' 'GALEY_040' 'GALEY_050' 'GLASHACOONCORE_010'
#  'GLASHOREAG_010' 'GLENNAHOO_010' 'KNOCKFINNISK_010' 'LEE (TRALEE)_010'
#  'LEE (TRALEE)_020' 'LEE (TRALEE)_030' 'LYRACRUMPANE_010' 'OOLAGH_010'
#  'OOLAGH_020' 'OWENCASHLA_010' 'OWENAFEANNA_010' 'OWVEG (KERRY)_010'
#  'OWVEG (KERRY)_020' 'SCORID_010' 'SMEARLAGH_010' 'SMEARLAGH_020'
#  'SMEARLAGH_030' 'SMEARLAGH_040' 'TULLALEAGUE_010' 'TYSHE_010' 'TYSHE_020'
#  'TARMON STREAM_010' 'AHACRONANE_010' 'AHACRONANE_020'
#  'AHAVARRAGA STREAM_010' 'ARRA_010' 'DEEL (NEWCASTLEWEST)_090'
# ...

# %%
print(f"Number of unique rivers in the specified local authority areas: {len(unique_rivers_authorities)}")
# Out:
# Number of unique rivers in the specified local authority areas: 347

# %% [markdown]
# ### There are still many rivers to analize, so let's reduce the local authority to 'Tipperary County Council' only

# %%
# Filter rows where'RiverBasinDistrict' is 'Shannon'
filtered_df = name_rivers[name_rivers['RiverBasinDistrict'] == 'Shannon']

# Filter rows by specific local authority
filtered_authority_df = filtered_df[filtered_df['LocalAuthority'] == 'Tipperary County Council']

# Eliminate duplicates in the 'RiverWaterbodyName' column
unique_rivers_authority = filtered_authority_df['RiverWaterbodyName'].dropna().drop_duplicates().unique()

print(f"\nUnique rivers in the area of Tipperary County Council:")
print(unique_rivers_authority)
# Out:
# Unique rivers in the area of Tipperary County Council:
# ['DRUMCOMOGE_010' 'MAHORE_010' 'ANNAGH (TIPPERARY)_010'
#  'ANNAGH (TIPPERARY)_020' 'ANNAGH (TIPPERARY)_030' 'ARDGREGANE STREAM_010'
#  'ARDGREGANE STREAM_020' 'SHANNON (LOWER)_040' 'ARDCRONY STREAM_010'
#  'BALLINTOTTY_010' 'BALLINTOTTY_020' 'BALLYFINBOY_020' 'BALLYFINBOY_030'
#  'BALLYFINBOY_040' 'BALLYFINBOY_050' 'BALLYFINBOY_060' 'BALLYFINBOY_070'
#  'BILBOA_010' 'BUNOW_010' 'BUNOW_020' 'NENAGH_050' 'CAHERNAHALLIA_010'
#  'CAHERNAHALLIA_020' 'CAUTEEN_010' 'CAPPAWHITE STREAM_010' 'DEAD_020'
#  'NENAGH_060' 'CARRIGAHORIG STREAM_010' 'DEAD_010' 'DOONANE_010'
#  'DOLLA_010' 'GORTNAGERAGH_010' 'GRANGE (TIPPERARY)_010' 'NENAGH_020'
#  'KILMASTULLA_030' 'INCH (BILBOA)_010' 'KILMASTULLA_010' 'KILMASTULLA_020'
#  'KILMASTULLA_040' 'KILMASTULLA_050' 'KILFADDA CASTLE STREAM_010'
#  'LORRHA STREAM_010' 'LORRHA STREAM_020' 'NENAGH_010' 'NENAGH_030'
#  'NENAGH_040' 'NENAGH_070' 'NEWPORT (TIPPERARY)_010'
# ...

# %%
print(f"Number of unique rivers in the area of Tipperary County Council: {len(unique_rivers_authority)}")
# Out:
# Number of unique rivers in the area of Tipperary County Council: 62

# %%
# pip install geopandas matplotlib
# Out:
# ...
#
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Cargar datos geoespaciales desde un archivo shapefile 
monitoring_gdf = gpd.read_file('Dataset_selected/MON_QStations/Mon_QStations_12012024.shp')

# Crear un plot de los ríos
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
monitoring_gdf.plot(ax=ax, color='blue', linewidth=1)
ax.set_title('Stations in Ireland')
plt.show()

# %%
# Cargar datos geoespaciales desde un archivo shapefile 
rivers_gdf = gpd.read_file('Dataset_selected/RiversandLakes/Shapefiles/WATER_RivNetRoutes.shp')

# Crear un plot de los ríos
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
rivers_gdf.plot(ax=ax, color='blue', linewidth=1)
ax.set_title('Rivers in Ireland')
plt.show()

# %%
# pip install geopandas folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Mostrar las primeras filas del DataFrame para explorar las columnas
print(rivers_gdf.head())
# Mostrar las columnas disponibles
print(rivers_gdf.columns)
# Out:
#    OBJECTID    SEG_CD   EPA_NAME EPA_CODE  ORDER_ CONTINUA  \
# 0    350347      01_1       None     None       1     None
# 1    350348     01_10       None     None       1     None
# 2    350349    01_100       None     None       1     None
# 3    350350  01_100_1       None     None       1        L
# 4    350351   01_1000  KINLETTER    01K01       1     None
#
#                RWB_CD LWB_CD TWB_CD   SegmentLen CWB_CD   Shape_STLe  \
# 0  UKGBNI1NW010104068   None   None   506.781480   None   506.781480
# 1     IE_NW_01R010200   None   None   138.787088   None   138.787088
# 2     IE_NW_01D330890   None   None   515.945669   None   515.945669
# 3     IE_NW_01C060100   None   None   165.915801   None   165.915801
# 4  UKGBNI1NW010102066   None   None  1009.215024   None  1009.215024
#
#                                             geometry
# 0  LINESTRING Z (203313.660 380898.520 325.883, 2...
# 1  LINESTRING Z (195519.880 396827.260 264.072, 1...
# ...

# %% [markdown]
# # Analize some pameters for each selected river

# %% [markdown]
# ### 62 rivers were selected and information was found in 46 of them, so all of them will be joined in a DataFrame to perform the correponding EDA (a file had to be downloaded for each river on the EPA website)

# %%
import os

folder_path = "Dataset_selected/Rivers_Tipperary"
files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

data_frames = []
for file in files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    data_frames.append(df)

# Unir todos los DataFrames en uno solo
combined_df = pd.concat(data_frames, ignore_index=True)
combined_df
# Out:
#                   WaterbodyName    WaterbodyCode Waterbodytype  \
# 0        ANNAGH (TIPPERARY)_020  IE_SH_25A020200         River
# 1        ANNAGH (TIPPERARY)_020  IE_SH_25A020200         River
# 2        ANNAGH (TIPPERARY)_020  IE_SH_25A020200         River
# 3        ANNAGH (TIPPERARY)_020  IE_SH_25A020200         River
# 4        ANNAGH (TIPPERARY)_020  IE_SH_25A020200         River
# ...                         ...              ...           ...
# 132984  YOUGHAL (TIPPERARY)_010  IE_SH_25Y020200         River
# 132985  YOUGHAL (TIPPERARY)_010  IE_SH_25Y020200         River
# 132986  YOUGHAL (TIPPERARY)_010  IE_SH_25Y020200         River
# 132987  YOUGHAL (TIPPERARY)_010  IE_SH_25Y020200         River
# 132988  YOUGHAL (TIPPERARY)_010  IE_SH_25Y020200         River
#
#        MonitoringStationCode MonitoringStationName MonitoringStationType  \
# 0                RS25A020200    Charlotte's Bridge           Operational
# ...

# %% [markdown]
# ### It can be seen see that some values of MonitoringStationLocalAuthority include several names, let's see which ones they contain since we only want to analyze 'Tipperary County Council'

# %%
# Display the unique names in the column 'MonitoringStationLocalAuthority'
unique_numbers = combined_df['MonitoringStationLocalAuthority'].unique()

# Display the unique names
print(unique_numbers)
# Out:
# ['Tipperary County Council' 'Offaly County Council'
#  'Limerick City & County Council' 'Galway County Council'
#  'Clare County Council']

# %%
# Filter the DataFrame with the name 'Tipperary County Council' in the column 'MonitoringStationLocalAuthority'
combined_df_tipperary = combined_df[combined_df['MonitoringStationLocalAuthority'] == 'Tipperary County Council']
combined_df_tipperary
# Out:
#                   WaterbodyName    WaterbodyCode Waterbodytype  \
# 0        ANNAGH (TIPPERARY)_020  IE_SH_25A020200         River
# 1        ANNAGH (TIPPERARY)_020  IE_SH_25A020200         River
# 2        ANNAGH (TIPPERARY)_020  IE_SH_25A020200         River
# 3        ANNAGH (TIPPERARY)_020  IE_SH_25A020200         River
# 4        ANNAGH (TIPPERARY)_020  IE_SH_25A020200         River
# ...                         ...              ...           ...
# 132984  YOUGHAL (TIPPERARY)_010  IE_SH_25Y020200         River
# 132985  YOUGHAL (TIPPERARY)_010  IE_SH_25Y020200         River
# 132986  YOUGHAL (TIPPERARY)_010  IE_SH_25Y020200         River
# 132987  YOUGHAL (TIPPERARY)_010  IE_SH_25Y020200         River
# 132988  YOUGHAL (TIPPERARY)_010  IE_SH_25Y020200         River
#
#        MonitoringStationCode MonitoringStationName MonitoringStationType  \
# 0                RS25A020200    Charlotte's Bridge           Operational
# ...

# %%
combined_df_tipperary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110481 entries, 0 to 132988
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   WaterbodyName                    110481 non-null  object
#  1   WaterbodyCode                    110481 non-null  object
#  2   Waterbodytype                    110481 non-null  object
#  3   MonitoringStationCode            110481 non-null  object
#  4   MonitoringStationName            110481 non-null  object
#  5   MonitoringStationType            110481 non-null  object
#  6   MonitoringStationLocalAuthority  110481 non-null  object
#  7   SampleCode                       110481 non-null  object
#  8   SampleDate                       110481 non-null  object
#  9   SampleMethod                     110481 non-null  object
#  10  ParameterName                    110481 non-null  object
# ...

# %%
unique_rivers = combined_df_tipperary['WaterbodyName'].unique()
print(unique_rivers)
# Out:
# ['ANNAGH (TIPPERARY)_020' 'ANNAGH (TIPPERARY)_030' 'BALLINTOTTY_010'
#  'BALLINTOTTY_020' 'BALLYFINBOY_030' 'BALLYFINBOY_040' 'BALLYFINBOY_050'
#  'BALLYFINBOY_070' 'BUNOW_010' 'BUNOW_020' 'CAHERNAHALLIA_010'
#  'CAHERNAHALLIA_020' 'CAPPAWHITE STREAM_010' 'CARRIGAHORIG STREAM_010'
#  'DEAD_010' 'DOONANE_010' 'GRANGE (TIPPERARY)_010'
#  'KILFADDA CASTLE STREAM_010' 'KILMASTULLA_010' 'KILMASTULLA_020'
#  'KILMASTULLA_030' 'KILMASTULLA_050' 'LORRHA STREAM_010'
#  'LORRHA STREAM_020' 'NENAGH_010' 'NENAGH_030' 'NENAGH_040' 'NENAGH_050'
#  'NENAGH_060' 'NENAGH_070' 'NEWPORT (TIPPERARY)_020'
#  'NEWPORT (TIPPERARY)_030' 'NEWPORT (TIPPERARY)_040' 'NEWTOWN_010'
#  'OLLATRIM_030' 'OLLATRIM_050' 'PALLAS_010' 'SHANNON (LOWER)_030'
#  'SMALL (TIPPERARY)_010' 'YOUGHAL (TIPPERARY)_010']

# %%
print(f"\nUnique rivers in the area of Tipperary County Council with rivers found:, {len(unique_rivers)}")
# Out:
# Unique rivers in the area of Tipperary County Council with rivers found:, 40

# %%
# Remove unnecessary columns
columns_to_drop = [
    'WaterbodyCode', 'MonitoringStationCode', 'MonitoringStationType', 'SampleCode', 'SampleMethod', 'ParameterUnitName', 'Result',
    'TextResult', 'ResultString', 'LimitOfDetection', 'ReportTextResult', 'ReportResultString', 'ReportLimit'
]

combined_df_tipperary.drop(columns=columns_to_drop, inplace=True)
combined_df_tipperary
# Out:
# C:\Users\TOSHIBA\AppData\Local\Temp\ipykernel_13700\3726186657.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df_tipperary.drop(columns=columns_to_drop, inplace=True)
#                   WaterbodyName Waterbodytype MonitoringStationName  \
# 0        ANNAGH (TIPPERARY)_020         River    Charlotte's Bridge
# 1        ANNAGH (TIPPERARY)_020         River    Charlotte's Bridge
# 2        ANNAGH (TIPPERARY)_020         River    Charlotte's Bridge
# 3        ANNAGH (TIPPERARY)_020         River    Charlotte's Bridge
# 4        ANNAGH (TIPPERARY)_020         River    Charlotte's Bridge
# ...                         ...           ...                   ...
# 132984  YOUGHAL (TIPPERARY)_010         River        Br. At Youghal
# ...

# %%
# Show information about null values in DataFrame columns
print(combined_df_tipperary.isnull().sum())
# Out:
# WaterbodyName                         0
# Waterbodytype                         0
# MonitoringStationName                 0
# MonitoringStationLocalAuthority       0
# SampleDate                            0
# ParameterName                         0
# ParameterUnitShortCode                0
# ReportResult                       4140
# dtype: int64

# %%
# Calculating the percentage of null values
total_rows = 110481
null_values = 4140
percentage_nulls = (null_values / total_rows) * 100
print(f"Percentage of null values: {percentage_nulls:.2f}%")
# Out:
# Percentage of null values: 3.75%

# %% [markdown]
# ## CASE ONE: Remove rows with null values

# %% [markdown]
# ### 4140 null values represents 3.75% of 110481 which is withing the accepted threshold of 5%, so rows with null values will be eliminated

# %%
# Remove the rows with null values in 'Result' column
combined_df_tipperary.dropna(subset=['ReportResult'], inplace=True)
combined_df_tipperary
# Out:
# C:\Users\TOSHIBA\AppData\Local\Temp\ipykernel_13700\3566426186.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df_tipperary.dropna(subset=['ReportResult'], inplace=True)
#                   WaterbodyName Waterbodytype MonitoringStationName  \
# 0        ANNAGH (TIPPERARY)_020         River    Charlotte's Bridge
# 1        ANNAGH (TIPPERARY)_020         River    Charlotte's Bridge
# 2        ANNAGH (TIPPERARY)_020         River    Charlotte's Bridge
# 3        ANNAGH (TIPPERARY)_020         River    Charlotte's Bridge
# 4        ANNAGH (TIPPERARY)_020         River    Charlotte's Bridge
# ...                         ...           ...                   ...
# 132984  YOUGHAL (TIPPERARY)_010         River        Br. At Youghal
# ...

# %%
# Save the DataFrame as a CSV file
combined_df_tipperary.to_csv('combined_df_tipperary.csv', index=False)
